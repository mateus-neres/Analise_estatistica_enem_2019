# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/projeto_de_analise_estatistica_enem_2019/blob/main/tratamento_enem_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROJETO DE ANÁLISE ESTATISTICA ENEM 2019**
#
# Este projeto analisa os resultados do ENEM no estado de São Paulo no ano de 2019.
#
# Os dados foram extraídos do site do INEP:
#
# http://inep.gov.br/mocrodados

# %%
import numpy as np
import pandas as pd

# %%
dados = pd.read_csv("/content/drive/MyDrive/curso_Udemy/curso_estatistica_python/microdados_enem_2019_sp.csv", sep=";", encoding="iso-8859-1" )
# encoding: codificação de caracteres, normalmente ultiza-se o "iso-8859-1", utf-8, latin-1

# %% [markdown]
# ##Exibindo colunas e linhas sem abreviações
#
# para exibir as colunas e linhas de um DataFrame sem abreviações, você pode usar o método pd.set_option do Pandas para configurar as opções de exibição.

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# #**Estração e limpesa dos dados**

# %%
dados.head()
# Out:
#   NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0     1,90E+11                  3546801            Santa Isabel
# 1     1,90E+11                  3538204             Pinhalzinho
# 2     1,90E+11                  3550308               São Paulo
# 3     1,90E+11                  3548708   São Bernardo do Campo
# 4     1,90E+11                  3549409    São Joaquim da Barra
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        22       M                1
# 1                35               SP        19       M                1
# 2                35               SP        17       F                1
# 3                35               SP        19       M                1
# 4                35               SP        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  CO_MUNICIPIO_NASCIMENTO  \
# 0            3                 1                1506500.0
# ...

# %%
#O número total de inscrito em são Paulo foi de 813772, sendo de 15,97% de todo o Brasil que foi de 50955308 inscritos
dados.shape # vai passar (813772, 44) -> (linhas, registros ou atributos)
# Out:
# (813772, 44)

# %%
#Ánalise dos tipos de atributos
#Object: string
#int64: inteiros
#float64: reais
#complex: complexos
dados.dtypes
# Out:
# NU_INSCRICAO                object
# CO_MUNICIPIO_RESIDENCIA      int64
# NO_MUNICIPIO_RESIDENCIA     object
# CO_UF_RESIDENCIA             int64
# SG_UF_RESIDENCIA            object
# NU_IDADE                     int64
# TP_SEXO                     object
# TP_ESTADO_CIVIL              int64
# TP_COR_RACA                  int64
# TP_NACIONALIDADE             int64
# CO_MUNICIPIO_NASCIMENTO    float64
# NO_MUNICIPIO_NASCIMENTO     object
# CO_UF_NASCIMENTO           float64
# SG_UF_NASCIMENTO            object
# TP_ST_CONCLUSAO              int64
# TP_ANO_CONCLUIU              int64
# TP_ESCOLA                    int64
# TP_ENSINO                  float64
# IN_TREINEIRO                 int64
# CO_ESCOLA                  float64
# CO_MUNICIPIO_ESC           float64
# NO_MUNICIPIO_ESC            object
# CO_UF_ESC                  float64
# SG_UF_ESC                   object
# TP_DEPENDENCIA_ADM_ESC     float64
# TP_LOCALIZACAO_ESC         float64
# TP_SIT_FUNC_ESC            float64
# ...

# %% [markdown]
# Removendo colunas desnecessárias

# %%
dados1 = dados.drop(columns=["CO_UF_RESIDENCIA","SG_UF_RESIDENCIA","CO_MUNICIPIO_NASCIMENTO","CO_MUNICIPIO_RESIDENCIA","NO_MUNICIPIO_NASCIMENTO","CO_UF_NASCIMENTO","SG_UF_NASCIMENTO","TP_ANO_CONCLUIU", "TP_ENSINO","CO_MUNICIPIO_ESC","CO_UF_ESC", "SG_UF_ESC","TP_DEPENDENCIA_ADM_ESC","TP_LOCALIZACAO_ESC","TP_SIT_FUNC_ESC"], )

# %%
dados1.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0     1,90E+11            Santa Isabel        22       M                1
# 1     1,90E+11             Pinhalzinho        19       M                1
# 2     1,90E+11               São Paulo        17       F                1
# 3     1,90E+11   São Bernardo do Campo        19       M                1
# 4     1,90E+11    São Joaquim da Barra        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ESCOLA  IN_TREINEIRO  \
# 0            3                 1                1          1             0
# 1            3                 1                1          1             0
# 2            3                 1                2          3             0
# 3            3                 1                2          2             0
# 4            1                 1                1          1             0
#
# ...

# %%
dados1.shape
# Out:
# (813772, 29)

# %% [markdown]
# #**Renomear varias colunas**

# %%
# Aplicando em apenas uma coluna
dados1 = dados1.rename(columns={"NU_NOTA_REDACAO":"NOTA_REDACAO"})

# %%
# Aplicando em varias colunas
dados1 = dados1.rename(columns={"NU_NOTA_CN":"NOTA_CN", "NU_NOTA_CH":"NOTA_CH",
                                "NU_NOTA_LC":"NOTA_LC", "NU_NOTA_MT":"NOTA_MT"})

# %%
dados1 = dados1.rename(columns={"NU_INSCRICAO":"INSCRICAO","NO_MUNICIPIO_RESIDENCIA":"MUNICIPIO_RESIDENCIA",
                                "NU_IDADE":"IDADE", "TP_SEXO":"SEXO","TP_ESTADO_CIVIL":"ESTADO_CIVIL",
                                "TP_COR_RACA":"RACA", "TP_NACIONALIDADE":"NACIONALIDADE","TP_ESCOLA":"ESCOLA","Q025":"INTERNET"})

# %%
dados1 = dados1.rename(columns={"NU_NOTA_COMP1":"COMP1","NU_NOTA_COMP2":"COMP2","NU_NOTA_COMP3":"COMP3","NU_NOTA_COMP4":"COMP4","NU_NOTA_COMP5":"COMP5"})

# %%
dados1 = dados1.rename(columns={"TP_LINGUA":"LINGUA"})

# %%
dados1.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL  RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1     3
# 1  1,90E+11            Pinhalzinho     19    M             1     3
# 2  1,90E+11              São Paulo     17    F             1     3
# 3  1,90E+11  São Bernardo do Campo     19    M             1     3
# 4  1,90E+11   São Joaquim da Barra     37    M             2     1
#
#    NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1       1             0         NaN
# 1              1                1       1             0         NaN
# 2              1                2       3             0  15567761.0
# 3              1                2       2             0  35904958.0
# 4              1                1       1             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 0                    NaN               1               1               1
# ...

# %% [markdown]
# #**Conrrigindo erro nas notas individuais**

# %%
dados1.loc[:,"NOTA_CN"] /= 10
dados1.loc[:,"NOTA_CH"] /= 10
dados1.loc[:,"NOTA_LC"] /= 10
dados1.loc[:,"NOTA_MT"] /= 10

# %%
display(dados1.head(5))
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL  RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1     3
# 1  1,90E+11            Pinhalzinho     19    M             1     3
# 2  1,90E+11              São Paulo     17    F             1     3
# 3  1,90E+11  São Bernardo do Campo     19    M             1     3
# 4  1,90E+11   São Joaquim da Barra     37    M             2     1
#
#    NACIONALIDADE  TP_ST_CONCLUSAO  ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1       1             0         NaN
# 1              1                1       1             0         NaN
# 2              1                2       3             0  15567761.0
# 3              1                2       2             0  35904958.0
# 4              1                1       1             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 0                    NaN               1               1               1
# ...

# %% [markdown]
# ##**Reanomear registros (linha)**

# %%
dados1["RACA"] = dados1["RACA"].replace({0:"não_declarado", 1:"branca", 2:"preta",3:"parda",4:"amarela",5:"indígena"})
dados1["INTERNET"] = dados1["INTERNET"].replace({"A":"não", "B":"sim"})
# Outra maneira de fazer:
# Exp: dados1["INTERNET"] = dados1["INTERNET"].replace(["A","B"], ["não","sim"])

# %%
dados1["ESCOLA"] = dados1["ESCOLA"].replace([1,2,3,4], ["não_respondeu","pública","privada","exterior"])

# %%
dados1["LINGUA"] = dados1["LINGUA"].replace([0,1],["inglês","espanhol"])

# %%
dados1.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11            Pinhalzinho     19    M             1   parda
# 2  1,90E+11              São Paulo     17    F             1   parda
# 3  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 4  1,90E+11   São Joaquim da Barra     37    M             2  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1  não_respondeu             0         NaN
# 1              1                1  não_respondeu             0         NaN
# 2              1                2        privada             0  15567761.0
# 3              1                2        pública             0  35904958.0
# 4              1                1  não_respondeu             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %% [markdown]
# #**Análise exploratória e Transformação dos dados**

# %% [markdown]
# **Análise das idades**

# %%
dados1["IDADE"].value_counts()
# Out:
# 17    219313
# 18    147548
# 19     81236
# 16     59316
# 20     53009
# 21     37242
# 22     29489
# 23     23531
# 24     18851
# 25     15103
# 26     12465
# 15     11583
# 27     10367
# 28      8986
# 29      7650
# 30      6967
# 31      6331
# 32      5685
# 33      5175
# 34      4795
# 35      4340
# 36      4109
# 37      4105
# 38      3767
# 39      3299
# 40      3058
# 41      2638
# 42      2462
# 43      2307
# 44      2069
# 45      1939
# 46      1718
# 47      1578
# 48      1496
# 49      1304
# 50      1167
# 51      1014
# 52       933
# 53       841
# 54       727
# 55       652
# 56       530
# 57       497
# 58       388
# 14       355
# 59       325
# 60       254
# 61       236
# 62       176
# 63       144
# 64       139
# 65       115
# 66        81
# 67        72
# 68        53
# 69        43
# 70        40
# 13        29
# 71        25
# 72        17
# 73        16
# 74        13
# 75        10
# 76         8
# 12         6
# 8          6
# ...

# %%
dados1["IDADE"].value_counts().sort_index()
# Out:
# 2          1
# 3          1
# 4          1
# 5          2
# 6          2
# 7          3
# 8          6
# 12         6
# 13        29
# 14       355
# 15     11583
# 16     59316
# 17    219313
# 18    147548
# 19     81236
# 20     53009
# 21     37242
# 22     29489
# 23     23531
# 24     18851
# 25     15103
# 26     12465
# 27     10367
# 28      8986
# 29      7650
# 30      6967
# 31      6331
# 32      5685
# 33      5175
# 34      4795
# 35      4340
# 36      4109
# 37      4105
# 38      3767
# 39      3299
# 40      3058
# 41      2638
# 42      2462
# 43      2307
# 44      2069
# 45      1939
# 46      1718
# 47      1578
# 48      1496
# 49      1304
# 50      1167
# 51      1014
# 52       933
# 53       841
# 54       727
# 55       652
# 56       530
# 57       497
# 58       388
# 59       325
# 60       254
# 61       236
# 62       176
# 63       144
# 64       139
# 65       115
# 66        81
# 67        72
# 68        53
# 69        43
# 70        40
# ...

# %% [markdown]
# **Alguns valores estranhos, idade menores que 12 e idade maiores que 80.**

# %%
# Inscrições abaixo de 12 anos, serão excluídas devido a alta probabilidade de erro.
menores_12 = dados1.query("IDADE < 12")["MUNICIPIO_RESIDENCIA"].value_counts()

# %%
menores_12
# Out:
# São Paulo                 5
# Tambaú                    1
# Ribeirão Preto            1
# Bálsamo                   1
# São Bernardo do Campo     1
# Embu das Artes            1
# Queiroz                   1
# Santana de Parnaíba       1
# Vargem Grande Paulista    1
# Auriflama                 1
# Araçatuba                 1
# Campinas                  1
# Name: MUNICIPIO_RESIDENCIA, dtype: int64

# %%
dados_maior_11 = dados1.loc[dados1.IDADE > 11]

# %%
dados_maior_11.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11            Pinhalzinho     19    M             1   parda
# 2  1,90E+11              São Paulo     17    F             1   parda
# 3  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 4  1,90E+11   São Joaquim da Barra     37    M             2  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1  não_respondeu             0         NaN
# 1              1                1  não_respondeu             0         NaN
# 2              1                2        privada             0  15567761.0
# 3              1                2        pública             0  35904958.0
# 4              1                1  não_respondeu             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %%
dados_maior_11["IDADE"].value_counts().sort_index()
# Out:
# 12         6
# 13        29
# 14       355
# 15     11583
# 16     59316
# 17    219313
# 18    147548
# 19     81236
# 20     53009
# 21     37242
# 22     29489
# 23     23531
# 24     18851
# 25     15103
# 26     12465
# 27     10367
# 28      8986
# 29      7650
# 30      6967
# 31      6331
# 32      5685
# 33      5175
# 34      4795
# 35      4340
# 36      4109
# 37      4105
# 38      3767
# 39      3299
# 40      3058
# 41      2638
# 42      2462
# 43      2307
# 44      2069
# 45      1939
# 46      1718
# 47      1578
# 48      1496
# 49      1304
# 50      1167
# 51      1014
# 52       933
# 53       841
# 54       727
# 55       652
# 56       530
# 57       497
# 58       388
# 59       325
# 60       254
# 61       236
# 62       176
# 63       144
# 64       139
# 65       115
# 66        81
# 67        72
# 68        53
# 69        43
# 70        40
# 71        25
# 72        17
# 73        16
# 74        13
# 75        10
# 76         8
# 77         3
# ...

# %% [markdown]
# **Treineiro**

# %%
dados_maior_11.query("IN_TREINEIRO == 1")["IN_TREINEIRO"].value_counts()
# Out:
# 1    93988
# Name: IN_TREINEIRO, dtype: int64

# %%
treineiros = dados_maior_11.loc[dados_maior_11.IN_TREINEIRO == 1]

# %%
treineiros.head()
# Out:
#     INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 20   1,90E+11               Santos     15    F             1   parda
# 21   1,90E+11             Panorama     16    F             1   parda
# 106  1,90E+11            São Paulo     16    F             1  branca
# 109  1,90E+11     Águas de Lindóia     16    M             1  branca
# 159  1,90E+11     Águas de Lindóia     15    M             1  branca
#
#      NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO  CO_ESCOLA  \
# 20               1                3  não_respondeu             1        NaN
# 21               1                3  não_respondeu             1        NaN
# 106              1                3  não_respondeu             1        NaN
# 109              1                3  não_respondeu             1        NaN
# 159              1                3  não_respondeu             1        NaN
#
#     NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %%
treineiros.to_csv("treineiros_enem_2019_sp.csv", encoding = "iso-8859-1", index = False)

# %%
# Separação entre vestibulando e treineiros
vestibulandos = dados_maior_11.loc[dados_maior_11.IN_TREINEIRO == 0]

# %%
vestibulandos.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11            Pinhalzinho     19    M             1   parda
# 2  1,90E+11              São Paulo     17    F             1   parda
# 3  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 4  1,90E+11   São Joaquim da Barra     37    M             2  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1  não_respondeu             0         NaN
# 1              1                1  não_respondeu             0         NaN
# 2              1                2        privada             0  15567761.0
# 3              1                2        pública             0  35904958.0
# 4              1                1  não_respondeu             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %%
vestibulandos.shape
# Out:
# (719768, 29)

# %% [markdown]
# **Análise das presenças**

# %%
vestibulandos["TP_PRESENCA_CN"].value_counts()
# Out:
# 1    500805
# 0    218693
# 2       270
# Name: TP_PRESENCA_CN, dtype: int64

# %%
vestibulandos["TP_PRESENCA_CH"].value_counts()
# Out:
# 1    533142
# 0    185969
# 2       657
# Name: TP_PRESENCA_CH, dtype: int64

# %%
vestibulandos["TP_PRESENCA_LC"].value_counts()
# Out:
# 1    533142
# 0    185969
# 2       657
# Name: TP_PRESENCA_LC, dtype: int64

# %%
vestibulandos["TP_PRESENCA_MT"].value_counts()
# Out:
# 1    500805
# 0    218693
# 2       270
# Name: TP_PRESENCA_MT, dtype: int64

# %% [markdown]
# ###RESULMO PRESENÇA NAS PROVAS
#
# CIÊNCIAS DA NATUREZA:
# 500805 Presentes,
# 218693 Faltaram e
# 270 Eliminados
#
# CIÊNCIAS HUMANAS:
# 533142 Presentes,
# 185969 Faltaram e
# 657 Eliminados
#
# LINGUAGEM E CÓDIGOS:
# 533142 Presentes,
# 185969 Faltaram e
# 657 Eliminados
#
# MATEMÁTICAT:
# 500805 Presentes,
# 218693 Faltaram e
# 270 Eliminados

# %%
vestibulandos["TP_STATUS_REDACAO"].value_counts().sort_index()
# Out:
# 1.0    519763
# 2.0       913
# 3.0      1417
# 4.0      5513
# 6.0      3626
# 7.0       543
# 8.0       828
# 9.0       539
# Name: TP_STATUS_REDACAO, dtype: int64

# %% [markdown]
# **valores ausentes**

# %%
vestibulandos["IDADE"].isnull().sum()
# Out:
# 0

# %%
provas = ["NOTA_REDACAO","NOTA_CN","NOTA_MT","NOTA_LC","NOTA_CH"]

# %%
# Registros NAN nas notas
vestibulandos [provas].isnull().sum()
# Out:
# NOTA_REDACAO    186626
# NOTA_CN         218963
# NOTA_MT         218963
# NOTA_LC         186626
# NOTA_CH         186626
# dtype: int64

# %%
vestibulandos_classificados = vestibulandos.loc[vestibulandos.TP_PRESENCA_CH == 1]
vestibulandos_classificados = vestibulandos_classificados.loc[vestibulandos_classificados.TP_PRESENCA_MT == 1]

# %%
vestibulandos_classificados["TP_PRESENCA_MT"].value_counts()
# Out:
# 1    499940
# Name: TP_PRESENCA_MT, dtype: int64

# %%
vestibulandos_classificados["TP_PRESENCA_CH"].value_counts()
# Out:
# 1    499940
# Name: TP_PRESENCA_CH, dtype: int64

# %%
vestibulandos_classificados["TP_PRESENCA_LC"].value_counts()
# Out:
# 1    499940
# Name: TP_PRESENCA_LC, dtype: int64

# %%
vestibulandos_classificados["TP_PRESENCA_CN"].value_counts()
# Out:
# 1    499940
# Name: TP_PRESENCA_CN, dtype: int64

# %%
vestibulandos_classificados[provas].isnull().sum()
# Out:
# NOTA_REDACAO    0
# NOTA_CN         0
# NOTA_MT         0
# NOTA_LC         0
# NOTA_CH         0
# dtype: int64

# %% [markdown]
# **Notas zeradas na redação**

# %%
vestibulandos_classificados.query("NOTA_REDACAO == 0")["NOTA_REDACAO"].value_counts()
# Out:
# 0.0    9181
# Name: NOTA_REDACAO, dtype: int64

# %%
vestibulandos_classificados.query("COMP1 == 0")["COMP1"].value_counts()
# Out:
# 0.0    9188
# Name: COMP1, dtype: int64

# %%
vestibulandos_classificados.query("COMP2 == 0")["COMP2"].value_counts()
# Out:
# 0.0    9181
# Name: COMP2, dtype: int64

# %%
vestibulandos_classificados.query("COMP3 == 0")["COMP3"].value_counts()
# Out:
# 0.0    9197
# Name: COMP3, dtype: int64

# %%
vestibulandos_classificados.query("COMP4 == 0")["COMP4"].value_counts()
# Out:
# 0.0    9194
# Name: COMP4, dtype: int64

# %%
vestibulandos_classificados.query("COMP5 == 0")["COMP5"].value_counts()
# Out:
# 0.0    73330
# Name: COMP5, dtype: int64

# %% [markdown]
# #**Resulmo notas 0 na redação**
#
# NOTA_REDAÇÂo: 9181 notas zeradas;
#
# COMP1: 9188 notas zeradas nesse componente;
#
# COMP2: 9181 notas zeradas nesse componente;
#
# COMP3: 9197 notas zeradas nesse componente;
#
# COMP4: 9188 notas zeradas nesse componente;
#
# COMP5: 73330 notas zeradas nesse componente;

# %%
vestibulandos_classificados.query("NOTA_CN == 0")["NOTA_CN"].value_counts()
# Out:
# 0.0    36
# Name: NOTA_CN, dtype: int64

# %%
vestibulandos_classificados.query("NOTA_MT == 0")["NOTA_MT"].value_counts()
# Out:
# 0.0    56
# Name: NOTA_MT, dtype: int64

# %%
vestibulandos_classificados.query("NOTA_CH == 0")["NOTA_CH"].value_counts()
# Out:
# 0.0    343
# Name: NOTA_CH, dtype: int64

# %%
vestibulandos_classificados.query("NOTA_LC == 0")["NOTA_LC"].value_counts()
# Out:
# 0.0    135
# Name: NOTA_LC, dtype: int64

# %% [markdown]
# ##Notas zero dos inscritos concorrentes ao vestibular:
#
# Ciências da Natureza: 36
#
# Ciências Humanas:343
#
# Linguagens e Códigos: 135
#
# Matemática: 56
#
# Redação: 9181

# %%
vestibulandos_classificados.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 2  1,90E+11              São Paulo     17    F             1   parda
# 3  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 5  1,90E+11             Embu-Guaçu     17    F             1   parda
# 8  1,90E+11              Guarulhos     23    F             1  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO   CO_ESCOLA  \
# 0              1                1  não_respondeu             0         NaN
# 2              1                2        privada             0  15567761.0
# 3              1                2        pública             0  35904958.0
# 5              1                2        pública             0         NaN
# 8              1                1  não_respondeu             0         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %%
vestibulandos_classificados = vestibulandos_classificados.drop(columns=["IN_TREINEIRO"],)

# %%
vestibulandos_classificados.shape
# Out:
# (499940, 28)

# %% [markdown]
# #**Exportação dos dados tratados em arquivo .csv**

# %%
vestibulandos_classificados.to_csv("enem_2019_tratado.csv", encoding = "iso-8859-1", index = False)

# %% [markdown]
# #**Referências e links úteis**
# **Referências Bibliográficas**
#
# LARSON, Ron. **Estatística Aplicada.** São Paulo: Pearson Prentice Hall, 2010.
#
# COSTA NETO, Pedro Luiz de Oliveira. **Estatística.** São Paulo: Bluncher, 2002.
#
# MORETTIN, Luiz Gonzaga. **Estatística Básica: probabilidade e inferência.** São Paulo: Pearson Prentice Hall, 2010.
#
#
#
# **LINKS ÚTEIS:**
#
# **Site INEP dos microdados do ENEM:**
#
# https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem
#
# **Estatística:**
#
# https://www.udemy.com/course/estatistica-com-linguagem-r/?referralCode=0DBFC727FE8574D5BCE8
#
# **Graus de liberdade:**
#
# https://pt.khanacademy.org/math/ap-statistics/summarizing-quantitative-data-ap/more-standard-deviation/v/another-simulation-giving-evidence-that-n-1-gives-us-an-unbiased-estimate-of-variance
#
# **Teste de Normalidade:**
#
# https://www.inf.ufsc.br/~vera.carmo/Testes_de_Hipoteses/Testes_aderencia.pdf
#
# **Bibliotecas Python**
#
# https://docs.python.org/pt-br/3/library/
#
# https://pandas.pydata.org/docs/
#
# https://docs.scipy.org/
#
# https://www.anaconda.com/products/individual
#
# **Gráficos**
#
# https://seaborn.pydata.org/index.html
#
# https://plotly.com/python/reference/#layout

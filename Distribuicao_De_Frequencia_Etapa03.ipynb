# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/projeto_de_analise_estatistica_enem_2019/blob/main/Distribuicao_De_Frequencia_Etapa03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**DISTRIBUÇÃO DE FRENQUÊNCIAS**

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
enem_sp = pd.read_csv("/content/drive/MyDrive/curso_Udemy/curso_estatistica_python/enem_2019_tratado.csv",
                      sep = ",", encoding = "iso-8859-1")

# %%
enem_sp.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11              São Paulo     17    F             1   parda
# 2  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 3  1,90E+11             Embu-Guaçu     17    F             1   parda
# 4  1,90E+11              Guarulhos     23    F             1  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0              1                1  não_respondeu         NaN  ...   600.2
# 1              1                2        privada  15567761.0  ...   731.8
# 2              1                2        pública  35904958.0  ...   393.2
# 3              1                2        pública         NaN  ...   419.2
# 4              1                1  não_respondeu         NaN  ...   796.1
#
#      LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# ...

# %%
enem_sorocaba = enem_sp.loc[enem_sp.MUNICIPIO_RESIDENCIA == "Sorocaba"]

# %%
enem_sorocaba.head()
# Out:
#     INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 42   1,90E+11             Sorocaba     27    F             1  branca
# 192  1,90E+11             Sorocaba     34    M             1  branca
# 226  1,90E+11             Sorocaba     24    F             1  branca
# 358  1,90E+11             Sorocaba     22    F             1  branca
# 409  1,90E+11             Sorocaba     34    F             2  branca
#
#      NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  CO_ESCOLA  ... NOTA_MT  \
# 42               1                1  não_respondeu        NaN  ...    49.1
# 192              1                1  não_respondeu        NaN  ...   751.3
# 226              1                1  não_respondeu        NaN  ...   609.8
# 358              1                1  não_respondeu        NaN  ...   587.8
# 409              1                1  não_respondeu        NaN  ...   566.2
#
#        LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# ...

# %%
enem_sorocaba.shape
# Out:
# (8088, 28)

# %%
idades = enem_sorocaba["IDADE"]

# %%
idades
# Out:
# 42        27
# 192       34
# 226       24
# 358       22
# 409       34
#           ..
# 499512    23
# 499592    17
# 499619    17
# 499646    18
# 499839    20
# Name: IDADE, Length: 8088, dtype: int64

# %%
freq_absoluta = Counter(idades)

# %%
freq_absoluta

# %%
freq_absoluta = pd.DataFrame.from_dict(freq_absoluta, orient="index")

# %%
freq_absoluta.head()

# %%
freq_absoluta = freq_absoluta.sort_index(ascending=True)
freq_absoluta.head()
# Out:
#        0
# 14     1
# 15     3
# 16     8
# 17  2993
# 18  1558

# %%
freq_relativa = freq_absoluta / freq_absoluta.sum()
freq_relativa.head()
# Out:
#            0
# 14  0.000124
# 15  0.000371
# 16  0.000989
# 17  0.370054
# 18  0.192631

# %%
freq_relativa_perc = freq_relativa * 100
freq_relativa_perc.head()
# Out:
#             0
# 14   0.012364
# 15   0.037092
# 16   0.098912
# 17  37.005440
# 18  19.263106

# %% [markdown]
# #**HISTOGRAMA**

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
enem_sorocaba.IDADE.hist(bins=8)
plt.title("Distribuição de Idade - Enem SP 2019 Sorocaba")
plt.show()

# %%
plt.hist(enem_sorocaba.IDADE, 8, rwidth=1)
plt.title("Distribução de Idade - Enem SP 2019 Sorocaba")
plt.show()

# %%
from matplotlib import colors
plt.hist(enem_sorocaba.IDADE, 10, rwidth=1, color="red", density = True)
plt.title("Distribuição de Idade - Enem SP 2019 - Sorocaba")
plt.xlabel("Idade")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# **Seaborn**

# %%
import seaborn as sns

# %%
sns.distplot(enem_sorocaba["IDADE"], bins=8, color="brown", kde=True)
# Out:
# <ipython-input-155-53590a098568>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='IDADE', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
sns.histplot(enem_sorocaba["IDADE"], bins=8, color="red");

# %%
sns.histplot(enem_sorocaba, x="IDADE", bins=8, color="orange", kde=True, stat="probability");

# %% [markdown]
# **Plotly**

# %%
import plotly.express as px

# %%
grafico = px.histogram (enem_sorocaba, x="IDADE", nbins=10, histnorm="percent")
grafico.update_layout(width=500,height=500,title_text="Distribuição de Idades - Enem SP 2019 - Sorocaba")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="IDADE", nbins=10, histnorm="probability")
grafico.update_layout(width=500,height=500,title_text="Distribuição de Idades por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="IDADE", nbins=10, histnorm="probability", color="SEXO")
grafico.update_layout(width=500,height=500,title_text="Distribuição de Idades por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="NOTA_MT", nbins=20, histnorm="probability", color=("SEXO"))
grafico.update_layout(width=500,height=500,title_text="Notas de Matemática por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="NOTA_CN", nbins=20, histnorm="probability", color=("SEXO"))
grafico.update_layout(width=500,height=500,title_text="Notas de Ciências naturais por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="NOTA_LC", nbins=20, histnorm="probability", color=("SEXO"))
grafico.update_layout(width=500,height=500,title_text="Notas de Linguagens e códigos por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="NOTA_REDACAO", nbins=20, histnorm="probability", color=("SEXO"))
grafico.update_layout(width=500,height=500,title_text="Notas de Redação por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico = px.histogram (enem_sorocaba, x="NOTA_REDACAO", nbins=20, histnorm="probability", color=("RACA"))
grafico.update_layout(width=800,height=800,title_text="Notas de Redação por Sexo - Enem SP 2019 - Sorocaba", title_font_color="red")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

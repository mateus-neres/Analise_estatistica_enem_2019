# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/projeto_de_analise_estatistica_enem_2019/blob/main/Distribuicao_De_Frequencia_Etapa03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**DISTRIBUÇÃO DE FRENQUÊNCIAS**

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
enem_sp = pd.read_csv("/content/drive/MyDrive/curso_Udemy/curso_estatistica_python/enem_2019_tratado.csv",
                      sep = ",", encoding = "iso-8859-1")

# %%
enem_sp.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11              São Paulo     17    F             1   parda
# 2  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 3  1,90E+11             Embu-Guaçu     17    F             1   parda
# 4  1,90E+11              Guarulhos     23    F             1  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0              1                1  não_respondeu         NaN  ...   600.2
# 1              1                2        privada  15567761.0  ...   731.8
# 2              1                2        pública  35904958.0  ...   393.2
# 3              1                2        pública         NaN  ...   419.2
# 4              1                1  não_respondeu         NaN  ...   796.1
#
#      LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 0    inglês                1.0  160.0  200.0  180.0  200.0  200.0
# 1    inglês                1.0  160.0  120.0  200.0  200.0  200.0
# 2  espanhol                1.0   80.0  160.0  120.0  100.0  100.0
# 3    inglês                1.0  120.0  120.0  120.0  120.0   80.0
# 4    inglês                1.0  160.0  200.0  180.0  180.0  160.0
#
#    NOTA_REDACAO INTERNET
# 0         940.0      sim
# 1         880.0      não
# 2         560.0      sim
# 3         560.0      sim
# 4         880.0      sim
#
# [5 rows x 28 columns]

# %%
enem_sorocaba = enem_sp.loc[enem_sp.MUNICIPIO_RESIDENCIA == "Sorocaba"]

# %%
enem_sorocaba
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 42      1,90E+11             Sorocaba     27    F             1  branca
# 192     1,90E+11             Sorocaba     34    M             1  branca
# 226     1,90E+11             Sorocaba     24    F             1  branca
# 358     1,90E+11             Sorocaba     22    F             1  branca
# 409     1,90E+11             Sorocaba     34    F             2  branca
# ...          ...                  ...    ...  ...           ...     ...
# 499512  1,90E+11             Sorocaba     23    F             1  branca
# 499592  1,90E+11             Sorocaba     17    F             1  branca
# 499619  1,90E+11             Sorocaba     17    F             1  branca
# 499646  1,90E+11             Sorocaba     18    F             1  branca
# 499839  1,90E+11             Sorocaba     20    F             1  branca
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ...  \
# 42                  1                1  não_respondeu         NaN  ...
# 192                 1                1  não_respondeu         NaN  ...
# 226                 1                1  não_respondeu         NaN  ...
# 358                 1                1  não_respondeu         NaN  ...
# 409                 1                1  não_respondeu         NaN  ...
# ...               ...              ...            ...         ...  ...
# 499512              1                1  não_respondeu         NaN  ...
# 499592              1                2        pública  35155779.0  ...
# 499619              1                2        privada  35111867.0  ...
# 499646              1                1  não_respondeu         NaN  ...
# 499839              1                1  não_respondeu         NaN  ...
#
#        NOTA_MT    LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 42        49.1  espanhol                1.0  140.0   40.0   40.0  140.0
# 192      751.3    inglês                1.0  120.0  120.0  140.0  120.0
# 226      609.8    inglês                1.0  100.0   40.0   80.0   80.0
# 358      587.8    inglês                1.0  120.0  180.0  140.0  120.0
# 409      566.2  espanhol                1.0  120.0  120.0  100.0  100.0
# ...        ...       ...                ...    ...    ...    ...    ...
# 499512   565.9    inglês                1.0  120.0  120.0  120.0  120.0
# 499592   662.7    inglês                1.0  160.0  200.0  180.0  200.0
# 499619   527.9    inglês                1.0  140.0  140.0  120.0  120.0
# 499646   463.7    inglês                1.0  140.0  120.0  120.0  120.0
# 499839    67.8    inglês                1.0  160.0  200.0  180.0  160.0
#
#         COMP5  NOTA_REDACAO INTERNET
# 42       40.0         400.0      sim
# 192      40.0         540.0      sim
# 226       0.0         300.0      sim
# 358     120.0         680.0      sim
# 409      60.0         500.0      sim
# ...       ...           ...      ...
# 499512   80.0         560.0      sim
# 499592  200.0         940.0      sim
# 499619  140.0         660.0      sim
# 499646  140.0         640.0      sim
# 499839   60.0         760.0      sim
#
# [8088 rows x 28 columns]

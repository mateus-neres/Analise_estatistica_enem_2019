# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/projeto_de_analise_estatistica_enem_2019/blob/main/amostragem_etapa02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROJETO DE ANÁLISE ESTATISTICA ENEM 2019**
#
# Este projeto analisa os resultados do ENEM no estado de São Paulo no ano de 2019.
#
# Os dados foram extraídos do site do INEP:
#
# http://inep.gov.br/mocrodados

# %% [markdown]
# #**2° ETAPA: AMOSTRAGENS**

# %% [markdown]
# ##Exportando bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Importando dataframe

# %%
enem_sp = pd.read_csv("/content/drive/MyDrive/curso_Udemy/curso_estatistica_python/enem_2019_tratado.csv", sep = ",", encoding = "iso-8859-1")

# %% [markdown]
# ##Exibindo colunas e linhas sem abreviações
#
# para exibir as colunas e linhas de um DataFrame sem abreviações, você pode usar o método pd.set_option do Pandas para configurar as opções de exibição.

# %%
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", None)
# pd.set_option("display.float_format", "{:.2f}".format)

# %%
enem_sp.head()
# Out:
#   INSCRICAO   MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 0  1,90E+11           Santa Isabel     22    M             1   parda
# 1  1,90E+11              São Paulo     17    F             1   parda
# 2  1,90E+11  São Bernardo do Campo     19    M             1   parda
# 3  1,90E+11             Embu-Guaçu     17    F             1   parda
# 4  1,90E+11              Guarulhos     23    F             1  branca
#
#    NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 0              1                1  não_respondeu         NaN
# 1              1                2        privada  15567761.0
# 2              1                2        pública  35904958.0
# 3              1                2        pública         NaN
# 4              1                1  não_respondeu         NaN
#
#         NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 0                    NaN               1               1               1
# ...

# %% [markdown]
# #**AREA DE AMOSTRAGEM SERÁ A CIDADE DE CAMPINAS-SP**

# %% [markdown]
# #Criando nova tabela com a amostragem de Campinas-SP

# %%
enem_campinas = enem_sp.loc[enem_sp.MUNICIPIO_RESIDENCIA == "Campinas"]

# %%
enem_campinas.head()
# Out:
#     INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 15   1,90E+11             Campinas     17    F             1  branca
# 31   1,90E+11             Campinas     19    F             1   parda
# 51   1,90E+11             Campinas     17    F             1  branca
# 116  1,90E+11             Campinas     17    F             1  branca
# 169  1,90E+11             Campinas     17    M             1  branca
#
#      NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 15               1                1  não_respondeu         NaN
# 31               1                1  não_respondeu         NaN
# 51               1                2        pública         NaN
# 116              1                2        pública  26078562.0
# 169              1                2        privada         NaN
#
#     NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 15               NaN               1               1               1
# ...

# %%
enem_campinas.shape
# Out:
# (13198, 28)

# %% [markdown]
# ##*AMOSTRAGEM ALEATÓRIA SIMPLES**
#
# Seleção execultadas por meio de sorteio sem nenhum filtro

# %%
np.random.seed(1) # Função seed serve para amarsenar o valor coletado aleatoriamente pelo python no valor desejado (1)

# %% [markdown]
# ###Separando a amostra com 20% do total da tabela enem_campinas com a função .sample(frac=0.20)

# %%
amostra_simples = enem_campinas.sample(frac=0.20) # Porcentagem

# %%
amostra_simples.head(5)
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 327999  1,90E+11             Campinas     20    M             1   preta
# 235222  1,90E+11             Campinas     17    F             1  branca
# 134221  1,90E+11             Campinas     18    F             1   parda
# 358407  1,90E+11             Campinas     25    M             0   parda
# 173364  1,90E+11             Campinas     18    M             1   parda
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 327999              1                1  não_respondeu         NaN
# 235222              1                2        pública  35018296.0
# 134221              1                2        pública         NaN
# 358407              1                1  não_respondeu         NaN
# 173364              1                1  não_respondeu         NaN
#
#        NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# ...

# %%
amostra_simples.shape
# Out:
# (2640, 28)

# %% [markdown]
# ###Podemos também coletar uma quantidade determinada de registro apenas digitando o valor de restros que desejamos .sample(3000)

# %%
amostra_simples = enem_campinas.sample(3000) # Quantidade numérica

# %%
amostra_simples.head(5)
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL     RACA  \
# 57191   1,90E+11             Campinas     17    F             1  amarela
# 215078  1,90E+11             Campinas     17    F             1    parda
# 430770  1,90E+11             Campinas     18    M             1   branca
# 409180  1,90E+11             Campinas     19    F             1    preta
# 429862  1,90E+11             Campinas     17    F             1   branca
#
#         NACIONALIDADE  TP_ST_CONCLUSAO   ESCOLA   CO_ESCOLA NO_MUNICIPIO_ESC  \
# 57191               1                2  pública  35045937.0         Campinas
# 215078              1                2  pública  35018880.0         Campinas
# 430770              1                2  privada  35112902.0         Campinas
# 409180              1                2  pública  35047120.0         Campinas
# 429862              1                2  pública  35812900.0         Campinas
#
# ...

# %%
amostra_simples.shape
# Out:
# (3000, 28)

# %% [markdown]
# ###Outra forma de obter uma amostragem

# %%
np.random.seed(2)

# %%
amostra = np.random.choice(a=[0,1], size=13198, replace=True, p=[0.8,0.2])

# %%
amostra
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
len(amostra[amostra == 0])
# Out:
# 10566

# %%
len(amostra[amostra == 1])
# Out:
# 2632

# %%
amostra_simples = enem_campinas.loc[amostra == 1]

# %%
amostra_simples.head(5)
# Out:
#      INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 949   1,90E+11             Campinas     17    F             1  branca
# 1058  1,90E+11             Campinas     19    M             1   parda
# 1980  1,90E+11             Campinas     17    F             1   parda
# 2053  1,90E+11             Campinas     18    F             1   parda
# 2328  1,90E+11             Campinas     20    F             1   parda
#
#       NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# 949               1                2        pública  35924573.0
# 1058              1                1  não_respondeu         NaN
# 1980              1                2        pública  35018302.0
# 2053              1                1  não_respondeu         NaN
# 2328              2                1  não_respondeu         NaN
#
#      NO_MUNICIPIO_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# 949          Campinas               1               1               1
# ...

# %% [markdown]
# #**AMOSTRAGEM SISTEMÁTICA**
#
# Os membros da população são ordenados numericamentes e selecionados aleatoriamente obedecendo uma ordem numérica.

# %%
enem_campinas.shape
# Out:
# (13198, 28)

# %%
np.random.seed(2)
inicio = np.random.choice(10,1)

# %%
amostra2 = np.arange(inicio,13198,100)
amostra2
# Out:
# array([    8,   108,   208,   308,   408,   508,   608,   708,   808,
#          908,  1008,  1108,  1208,  1308,  1408,  1508,  1608,  1708,
#         1808,  1908,  2008,  2108,  2208,  2308,  2408,  2508,  2608,
#         2708,  2808,  2908,  3008,  3108,  3208,  3308,  3408,  3508,
#         3608,  3708,  3808,  3908,  4008,  4108,  4208,  4308,  4408,
#         4508,  4608,  4708,  4808,  4908,  5008,  5108,  5208,  5308,
#         5408,  5508,  5608,  5708,  5808,  5908,  6008,  6108,  6208,
#         6308,  6408,  6508,  6608,  6708,  6808,  6908,  7008,  7108,
#         7208,  7308,  7408,  7508,  7608,  7708,  7808,  7908,  8008,
#         8108,  8208,  8308,  8408,  8508,  8608,  8708,  8808,  8908,
#         9008,  9108,  9208,  9308,  9408,  9508,  9608,  9708,  9808,
#         9908, 10008, 10108, 10208, 10308, 10408, 10508, 10608, 10708,
#        10808, 10908, 11008, 11108, 11208, 11308, 11408, 11508, 11608,
# ...

# %%
amostra_sistematica = enem_campinas.iloc[amostra2,:]

# %%
amostra_sistematica
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 401     1,90E+11             Campinas     18    F             1  branca
# 5079    1,90E+11             Campinas     18    F             1  branca
# 9218    1,90E+11             Campinas     19    F             1  branca
# 13685   1,90E+11             Campinas     20    M             1   parda
# 18239   1,90E+11             Campinas     20    M             1  branca
# ...          ...                  ...    ...  ...           ...     ...
# 481894  1,90E+11             Campinas     34    M             1   parda
# 485805  1,90E+11             Campinas     16    F             1  branca
# 488958  1,90E+11             Campinas     19    F             1  branca
# 492626  1,90E+11             Campinas     21    M             1  branca
# 496410  1,90E+11             Campinas     19    M             1   preta
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# ...

# %% [markdown]
# ###Outra forma de obter amostra sistemática

# %%
np.random.seed(30)

# %%
inicio = np.random.choice(10,1)
passo = np.random.randint(100,150,1)

# %%
passo
# Out:
# array([137])

# %%
inicio
# Out:
# array([5])

# %%
amostra2 = np.arange(inicio,13198,passo)
amostra
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
amostra2 = enem_campinas.iloc[amostra2,:]

# %%
amostra2
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 186     1,90E+11             Campinas     19    F             1  branca
# 6519    1,90E+11             Campinas     26    M             0   preta
# 12280   1,90E+11             Campinas     20    F             1  branca
# 18436   1,90E+11             Campinas     22    F             2   preta
# 23717   1,90E+11             Campinas     18    M             1   parda
# ...          ...                  ...    ...  ...           ...     ...
# 478519  1,90E+11             Campinas     23    F             1  branca
# 483431  1,90E+11             Campinas     18    F             1  branca
# 488340  1,90E+11             Campinas     19    F             1  branca
# 493180  1,90E+11             Campinas     33    F             0  branca
# 498126  1,90E+11             Campinas     17    M             1  branca
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  CO_ESCOLA  \
# ...

# %% [markdown]
# #**AMOSTRAGEM ESTRATIFICADA**
#
# Divisão da população em grupos e seleção aleatoria de uma amostra de cada grupo

# %%
 enem_campinas["RACA"].value_counts()
# Out:
# branca           7507
# parda            3652
# preta            1510
# amarela           279
# não_declarado     205
# indígena           45
# Name: RACA, dtype: int64

# %%
branca = enem_campinas.loc[enem_campinas.RACA == "branca"].sample(frac=0.10)

# %%
parda = enem_campinas[enem_campinas.RACA == "parda"].sample(frac=0.10)

# %%
preta = enem_campinas[enem_campinas.RACA == "preta"].sample(frac=0.10)

# %%
amarela = enem_campinas[enem_campinas.RACA == "preta"].sample(frac=0.10)

# %%
nd = enem_campinas[enem_campinas.RACA == "não_declarado"].sample(frac=0.10)

# %%
indigena = enem_campinas[enem_campinas.RACA == "indígena"].sample(frac=0.10)

# %%
amostra_estratificada = pd.concat([branca, parda, preta, amarela, nd, indigena])

# %%
amostra_estratificada
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL  \
# 439942  1,90E+11             Campinas     17    M             1
# 477692  1,90E+11             Campinas     30    M             1
# 398248  1,90E+11             Campinas     18    F             1
# 121597  1,90E+11             Campinas     27    F             0
# 316202  1,90E+11             Campinas     28    F             1
# ...          ...                  ...    ...  ...           ...
# 378318  1,90E+11             Campinas     32    M             1
# 485211  1,90E+11             Campinas     36    M             0
# 349878  1,90E+11             Campinas     17    F             1
# 114496  1,90E+11             Campinas     26    F             1
# 88722   1,90E+11             Campinas     18    F             1
#
#                  RACA  NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  \
# 439942         branca              1                2        pública
# ...

# %% [markdown]
# ###Técnica para quande quantidades de grupos

# %%
from sklearn.model_selection import train_test_split

# %%
X_treino, X_teste, y_treino, amostra_estratificada = train_test_split(enem_campinas.drop("RACA", axis=1), enem_campinas["RACA"],
                                                                      stratify=enem_campinas["RACA"], test_size=0.20)

# %%
amostra_estratificada.shape
# Out:
# (2640,)

# %%
amostra_estratificada.value_counts()
# Out:
# branca           1502
# parda             730
# preta             302
# amarela            56
# não_declarado      41
# indígena            9
# Name: RACA, dtype: int64

# %%
amostra_estratificada = amostra_estratificada.index

# %%
amostra_estratificada
# Out:
# Int64Index([269067, 142487, 187602, 189445, 310072,  33482, 213390, 449335,
#             178302, 356303,
#             ...
#             372339, 311165, 399721, 323424,  55811,  48202, 486966, 297513,
#             378574, 451917],
#            dtype='int64', length=2640)

# %%
amostra_estratificada_campinas = enem_campinas.loc[amostra_estratificada,:]

# %%
amostra_estratificada_campinas
# Out:
#        INSCRICAO MUNICIPIO_RESIDENCIA  IDADE SEXO  ESTADO_CIVIL    RACA  \
# 269067  1,90E+11             Campinas     40    M             0   parda
# 142487  1,90E+11             Campinas     17    F             1  branca
# 187602  1,90E+11             Campinas     17    M             1  branca
# 189445  1,90E+11             Campinas     26    M             1  branca
# 310072  1,90E+11             Campinas     18    M             1  branca
# ...          ...                  ...    ...  ...           ...     ...
# 48202   1,90E+11             Campinas     17    M             1  branca
# 486966  1,90E+11             Campinas     18    F             1  branca
# 297513  1,90E+11             Campinas     18    M             1   parda
# 378574  1,90E+11             Campinas     17    M             1  branca
# 451917  1,90E+11             Campinas     43    M             2   preta
#
#         NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# ...

# %% [markdown]
# #**AMOSTRAGEM POR CONGLOMERADO (AGRUPAMENTO)**

# %% [markdown]
# #**Referências e links úteis**
# **Referências Bibliográficas**
#
# LARSON, Ron. **Estatística Aplicada.** São Paulo: Pearson Prentice Hall, 2010.
#
# COSTA NETO, Pedro Luiz de Oliveira. **Estatística.** São Paulo: Bluncher, 2002.
#
# MORETTIN, Luiz Gonzaga. **Estatística Básica: probabilidade e inferência.** São Paulo: Pearson Prentice Hall, 2010.
#
#
#
# **LINKS ÚTEIS:**
#
# **Site INEP dos microdados do ENEM:**
#
# https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem
#
# **Estatística:**
#
# https://www.udemy.com/course/estatistica-com-linguagem-r/?referralCode=0DBFC727FE8574D5BCE8
#
# **Graus de liberdade:**
#
# https://pt.khanacademy.org/math/ap-statistics/summarizing-quantitative-data-ap/more-standard-deviation/v/another-simulation-giving-evidence-that-n-1-gives-us-an-unbiased-estimate-of-variance
#
# **Teste de Normalidade:**
#
# https://www.inf.ufsc.br/~vera.carmo/Testes_de_Hipoteses/Testes_aderencia.pdf
#
# **Bibliotecas Python**
#
# https://docs.python.org/pt-br/3/library/
#
# https://pandas.pydata.org/docs/
#
# https://docs.scipy.org/
#
# https://www.anaconda.com/products/individual
#
# **Gráficos**
#
# https://seaborn.pydata.org/index.html
#
# https://plotly.com/python/reference/#layout
